# %% [markdown]
# <a href="https://colab.research.google.com/github/sutharimanikanta/Golab/blob/main/VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications import VGG16
model1=VGG16()
# Out:
# ...
# 553467096/553467096 [==============================] - 24s 0us/step

# %%
# from keras import layers
# from keras.models import Sequential

# model = Sequential()

# model.add(layers.ZeroPadding2D((1, 1), input_shape=(224, 224, 3)))
# model.add(layers.Conv2D(64, (3, 3), activation="relu"))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(64, (3, 3), activation="relu"))
# model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(128, (3, 3), activation="relu"))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(128, (3, 3), activation="relu"))
# model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(256, (3, 3), activation="relu"))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(256, (3, 3), activation="relu"))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(256, (3, 3), activation="relu"))
# model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(512, (3, 3), activation="relu"))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(512, (3, 3), activation="relu"))
# model.add(layers.Conv2D(512, (3, 3), activation="relu"))
# model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(512, (3, 3), activation="relu"))
# model.add(layers.ZeroPadding2D((1, 1)))
# model.add(layers.Conv2D(512, (3, 3), activation="relu"))
# model.add(layers.Conv2D(512, (3, 3), activation="relu"))
# model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# model.add(layers.Flatten())  # Global Average Pooling instead of Flatten
# model.add(layers.Dense(4096, activation="relu"))  # Dense layer instead of Conv2D
# model.add(layers.Dropout(0.5))
# model.add(layers.Dense(4096, activation="relu"))
# model.add(layers.Dropout(0.5))
# model.add(layers.Dense(1000, activation="softmax"))  # Output layer with softmax activation

# model.summary()

# %%
from keras import layers
from keras.models import Sequential

model = Sequential()

model.add(layers.Conv2D(64, (3, 3), activation="relu", input_shape=(224, 224, 3)))
model.add(layers.Conv2D(64, (3, 3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation="relu"))
model.add(layers.Conv2D(128, (3, 3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

model.add(layers.Conv2D(256, (3, 3), activation="relu"))
model.add(layers.Conv2D(256, (3, 3), activation="relu"))
model.add(layers.Conv2D(256, (3, 3), activation="relu"))

model.add(layers.Conv2D(512, (3, 3), activation="relu"))
model.add(layers.Conv2D(512, (3, 3), activation="relu"))
model.add(layers.Conv2D(512, (3, 3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

model.add(layers.Conv2D(512, (3, 3), activation="relu"))
model.add(layers.Conv2D(512, (3, 3), activation="relu"))
model.add(layers.Conv2D(512, (3, 3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(4096, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4096, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1000, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_49 (Conv2D)          (None, 222, 222, 64)      1792
#
#  conv2d_50 (Conv2D)          (None, 220, 220, 64)      36928
#
#  max_pooling2d_18 (MaxPooli  (None, 110, 110, 64)      0
#  ng2D)
#
#  conv2d_51 (Conv2D)          (None, 108, 108, 128)     73856
#
#  conv2d_52 (Conv2D)          (None, 106, 106, 128)     147584
#
#  max_pooling2d_19 (MaxPooli  (None, 53, 53, 128)       0
#  ng2D)
#
#  conv2d_53 (Conv2D)          (None, 51, 51, 256)       295168
#
#  conv2d_54 (Conv2D)          (None, 49, 49, 256)       590080
#
#  conv2d_55 (Conv2D)          (None, 47, 47, 256)       590080
#
#  conv2d_56 (Conv2D)          (None, 45, 45, 512)       1180160
#
#  conv2d_57 (Conv2D)          (None, 43, 43, 512)       2359808
#
#  conv2d_58 (Conv2D)          (None, 41, 41, 512)       2359808
#
# ...

# %%
# !wget https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# Out:
# --2024-04-21 05:45:13--  https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.10.207, 142.251.12.207, 172.217.194.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.10.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58889256 (56M) [application/octet-stream]
# Saving to: ‘vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5’
#
# vgg16_weights_tf_di 100%[===================>]  56.16M  17.6MB/s    in 3.9s
#
# 2024-04-21 05:45:17 (14.3 MB/s) - ‘vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5’ saved [58889256/58889256]

# %% [markdown]
# # when layers mismatch use ," by_name=True " for weight in file format
# for directly downloading from the model
# from keras.applications import VGG16
#
# # Load pre-trained VGG16 model without top (fully connected) layers
# vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#
# # Loop through layers and load weights if layer names match
# for layer in model.layers:
#     if layer.name in vgg_model.layers:
#         layer.set_weights(vgg_model.get_layer(layer.name).get_weights())
#
# # Optionally, freeze layers from the pre-trained model
# for layer in model.layers:
#     layer.trainable = False

# %%
model.load_weights('/content/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input

# %%
def preprocessing_image(image_path):
    img = load_img(image_path, target_size=(224, 224))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

def findCosinesimilarity(source, test):


    a = np.dot(test, source)
    b = np.sum(np.square(source))
    c = np.sum(np.square(test))
    return 1 - (a / (np.sqrt(b) * np.sqrt(c)))

# %% [markdown]
# #ValueError: shapes (1,1000) and (1,1000) not aligned: 1000 (dim 1) != 1 (dim 0)
# use flatten( )

# %%
epsilon = 0.40

def verifyFace(img1, img2):
    img1=preprocessing_image(img1)
    img2=preprocessing_image(img2)
    img1_features = model.predict(img1)
    img2_features = model.predict(img2)
    sim = findCosinesimilarity(img1_features.flatten(), img2_features.flatten())
    return sim

# %%
img1_path = '/content/ryan.jpeg'
img2_path = '/content/ryan-reynolds.jpg'

# Display the images
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

img1 = image.load_img(img1_path)
axes[0].imshow(img1)
axes[0].set_title('Image 1')

img2 = image.load_img(img2_path)
axes[1].imshow(img2)
axes[1].set_title('Image 2')

plt.show()
similarity_score = verifyFace(img1_path,img2_path)
print("Similarity score between the two images:", similarity_score)
# Out:
# ...
# 1/1 [==============================] - 0s 24ms/step
# Similarity score between the two images: 0.001589357852935791

# %%
#!git clone https://github.com/SartajBhuvaji/Brain-Tumor-Classification-DataSet

# %%
import numpy as np
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16, preprocess_input
from scipy.spatial.distance import cosine

# Load pre-trained VGG16 model
model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Function to extract features from an image
def extract_features(image_path, model):
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    features = model.predict(img_array)
    return features.flatten()

# Function to calculate similarity between two feature vectors
def calculate_similarity(feature1, feature2):
    return 1 - cosine(feature1, feature2)

img1_path = '/content/ryan.jpeg'
img2_path = '/content/ryan-reynolds.jpg'
feature1 = extract_features(img1_path, model)
feature2 = extract_features(img2_path, model)
# Display the images
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

img1 = image.load_img(img1_path)
axes[0].imshow(img1)
axes[0].set_title('Image 1')

img2 = image.load_img(img2_path)
axes[1].imshow(img2)
axes[1].set_title('Image 2')

plt.show()
similarity_score = calculate_similarity(feature1, feature2)
print("Similarity score between the two images:", similarity_score)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x783e8457dd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 1/1 [==============================] - 0s 19ms/step
# Similarity score between the two images: 0.6684888005256653

# %%
from PIL import Image

def get_image_size(image_path):
    with Image.open(image_path) as img:
        width, height = img.size
    return width, height

img1_path = '/content/ryan.jpeg'
img2_path = '/content/ryan-reynolds.jpg'

width, height = get_image_size(img1_path)
print("Width:", width)
print("Height:", height)
# Out:
# Width: 474
# Height: 315

# %% [markdown]
# #ValueError: resize only works on single-segment arrays
# *

# %% [markdown]
# #ValueError: Failed to find data adapter that can handle input: <class 'PIL.JpegImagePlugin.JpegImageFile'>, <class 'NoneType'>
# *You are trying to use resize function on an array that is meant for an image object. Hence it is returning NoneType, which in turn is causing the issue.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load MNIST dataset
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Display some images from the dataset
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels[i])
plt.show()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, Conv2D, Flatten, Dense, Lambda
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
import tensorflow as tf

def euclidean_distance(vectors):
    vector1, vector2 = vectors
    sum_square = tf.keras.backend.sum(tf.keras.backend.square(vector1 - vector2), axis=1, keepdims=True)
    return tf.keras.backend.sqrt(tf.keras.backend.maximum(sum_square, tf.keras.backend.epsilon()))

def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

def contrastive_loss(y_true, y_pred):
    margin = 1
    square_pred = tf.keras.backend.square(y_pred)
    margin_square = tf.keras.backend.square(tf.keras.backend.maximum(margin - y_pred, 0))
    return tf.keras.backend.mean(y_true * square_pred + (1 - y_true) * margin_square)

def create_siamese_network(input_shape):
    input_layer = Input(shape=input_shape)
    conv1 = Conv2D(64, (10,10), activation='relu')(input_layer)
    conv2 = Conv2D(128, (7,7), activation='relu')(conv1)
    conv3 = Conv2D(128, (4,4), activation='relu')(conv2)
    conv4 = Conv2D(256, (4,4), activation='relu')(conv3)
    flat = Flatten()(conv4)
    dense = Dense(4096, activation='sigmoid')(flat)
    return Model(inputs=input_layer, outputs=dense)

def siamese_network(input_shape):
    input_a = Input(shape=input_shape)
    input_b = Input(shape=input_shape)
    model = create_siamese_network(input_shape)
    encoded_a = model(input_a)
    encoded_b = model(input_b)
    distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([encoded_a, encoded_b])
    return Model(inputs=[input_a, input_b], outputs=distance)

# Example usage
input_shape = (105, 105, 1)  # Input shape of your images
siamese_model = siamese_network(input_shape)
siamese_model.compile(optimizer=Adam(), loss=contrastive_loss)

# Train your Siamese network with pairs of images and their labels (0 for dissimilar, 1 for similar)
# x_train_pairs: Pair of images
# y_train_labels: Corresponding labels
siamese_model.fit([x_train_pairs[:, 0], x_train_pairs[:, 1]], y_train_labels, epochs=10, batch_size=128)
